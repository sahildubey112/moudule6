# %% [markdown]
# #Q1.  & Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5navigation links that are properly placed within the navigation bar using the CSS box model. The navigation items must change their text color on hover

# %%
from IPython.display import HTML
HTML="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        body{
            height: 2000px;
        }
        .container{
            height: 50px;
            width: 1000vw;
            background-color: blue;
            padding: 10px;
            position: fixed;
        }
       li{
            display: inline;
            text-decoration: none;
            list-style-type: none;
            margin: 20px;
            color: azure;
            border: 1px solid blue;
            padding: 15px;
            margin-top: 5px;

         }

         li:hover{
            background-color: red;
            color: white;
         }
         a{
            color: white;
            text-decoration: none;
            font-size: 25px;
         }

         a:hover{
            color: white;
         }

         #r1{
            margin-top: 5px;
         }


    </style>
</head>
<body>
    <div class="container">
        <ul id="r1">
            <li><a href="#">Home</a></li>
            <li><a href="#">About us</a></li>
            <li><a href="#">Contact us</a></li>
            <li><a href="#">Login</a></li>
            <li><a href="#">Blog</a></li>
        </ul>

    </div>

</body>
</html>
"""

# %% [markdown]
# #Q2. Create a div centered with an image and paragraph similar to the image mentioned below.

# %%
from IPython.display import HTML
HTML= """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>

        body{
            align-items: center;
            justify-content: center;

        }
        #container{
            height: 500px;
            width: 400px;
            background-color: yellow;
            border-radius: 30px;
         }
         #container2{
            height: 300px;
            width: 350px;
            background-image: url(pexels-photo-5905960.webp);
            background-position: center;
            background-size: cover;
            margin-left: 50px;
            margin: 0px auto;
            position: relative;
            bottom: -20px;
            border-radius: 30px;
         }

         #container3{
            position: relative;
            bottom: -50px;
            overflow: hidden;
            text-align: center;
            color: red;
         }
    </style>
</head>
<body>
    <div id="container">

        <div id="container2">

        </div>
        <div id="container3">
            Welcome to the exciting world of blogging! Whether you love sharing your expertise, expressing your creativity, or connecting with like-minded individuals, starting a blog opens up a world of possibilities. In this step-by-step guide, we'll talk you through everything you need to start your blogging journey with confidence.


        </div>

    </div>

</body>
</html>

"""

# %% [markdown]
# #Q3. & Create a navigation bar similar to question 1. For each navigation item, use a different border style.

# %%
from IPython.display import HTML
HTML= """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        #container1{
            height: 1000px;
            width: 1000px;
        }
        #box{
            height: 45px;
            width: 500px;
            background-color: blue;
            padding-left: 50px;
        }
        .box1{
            height: auto;
            width: auto;
            float: left;
            padding: 10px;
            font-weight: bold;
            font-size: 20px;
            border: 1px solid green;
            margin-left: 5px;
            margin-right: 5px;
            background-color: yellow;
            color: red;
        }
        .box2{
            height: auto;
            width: auto;
            float: left;
            padding: 10px;
            font-weight: bold;
            font-size: 20px;
            border: 1px solid black;
            margin-right: 5px;
            background-color: skyblue;
            color: red;
        }
        .box3{
            height: auto;
            width: auto;
            float: left;
            padding: 10px;
            font-weight: bold;
            font-size: 20px;
            border: 1px solid black;
            margin-right: 5px;
            background-color: pink;
            color: red;
        }

        .box4{
            height: auto;
            width: auto;
            float: left;
            padding: 10px;
            font-weight: bold;
            font-size: 20px;
            border: 1px solid black;
            margin-right: 5px;
            background-color: violet;
            color: red;
        }

        .box6{
            height: auto;
            width: auto;
            float: left;
            padding: 10px;
            font-weight: bold;
            font-size: 20px;
            border: 1px solid black;
            margin-right: 5px;
            background-color: green;
            color: red;

        }
        .box1:hover{
            background-color: indianred;
        }

        .box2:hover{
            background-color: indianred;
        }
        .box3:hover{
            background-color: indianred;
        }
        .box4:hover{
            background-color: indianred;
        }
        .box6:hover{
            background-color: indianred;
        }


    </style>
</head>
<body>
    <div class="container1">
        <div id="box">
        <div class="box1">Home</div>
        <div class="box2">About Us</div>
        <div class="box3">Contact Us</div>
        <div class="box4">Blog</div>
        <div class="box6">Login</div>
    </div>
    </div>

</body>
</html>
"""

# %% [markdown]
# #Q4. O& Create a simple webpage with an image and make the image circular using border-radius.

# %%
from IPython.display import HTML
HTML="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .container{
            height: 300px;
            width: 300px;
            background-image: url(premium_photo-1664281095326-e708fb4a48de.avif);
            background-position: center;
            background-size: cover;
            border-radius: 100%;

        }
    </style>
</head>
<body>
    <div class="container">

    </div>

</body>
</html>
"""

# %% [markdown]
# #Q5. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font align center to the page, below the heading have an image of Google fonts and a paragraph about Google fonts in font “Montserrat” paragraph font style should be“montserrat” font.

# %%
from IPython.display import HTML
HTML="""

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Google Fonts Blog</title>

    <style>

body {
    font-family: 'Montserrat', sans-serif;
    background-color: #f4f4f9;
    display: flex;
    justify-content: center;
    align-items: center;
    height: 100vh;
    margin: 0;
}


.container {
    text-align: center;
    background: white;
    padding: 20px;
    border-radius: 10px;
    box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
    max-width: 600px;
}


h1 {
    font-family: 'Oswald', sans-serif;
    font-size: 36px;
    color: #333;
    margin-bottom: 20px;
}


p {
    font-family: 'Montserrat', sans-serif;
    font-size: 18px;
    color: #555;
    line-height: 1.6;
}

    </style>
</head>
<body>

    <div class="container">
        <h1>Google Fonts</h1>
        <p>
            Google Fonts is a free and open-source collection of web fonts provided by Google. It allows developers and designers to use a variety of fonts in their projects without worrying about licensing issues.
            With an extensive library of font families, Google Fonts improves website typography and accessibility.
            The fonts can be embedded in web projects using a simple link or CSS import.
        </p>
    </div>

</body>
</html>

"""

# %% [markdown]
# #Q6. Create a simple website as mentioned in the below image. You can get the assets by visiting https://pwskills.com/about-us.

# %%
from IPython.display import HTML
HTML= """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style></style>
</head>
<body>
    <div class="container">
        <a href="https://pwskills.com/about-us/">

            <img src="pexels-photo-5905960.webp">
        </a>

    </div>

</body>
</html>
"""

# %% [markdown]
# #Q7. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.

# %%
from IPython.display import HTML
HTML="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>

        body{
            align-items: center;
            justify-content: center;

        }
        #container{
            height: 500px;
            width: 400px;
            background-color: yellow;
            border-radius: 30px;
         }
         #container2{
            height: 300px;
            width: 350px;
            background-image: url(pexels-photo-5905960.webp);
            background-position: center;
            background-size: cover;
            margin-left: 50px;
            margin: 0px auto;
            position: relative;
            bottom: -20px;
            border-radius: 30px;
         }

         #container3{
            position: relative;
            bottom: -50px;
            overflow: hidden;
            text-align: center;
            color: red;
         }
         #container2:hover{
            opacity: 0.5;
         }
    </style>
</head>
<body>
    <div id="container">

        <div id="container2">

        </div>
        <div id="container3">
            Welcome to the exciting world of blogging! Whether you love sharing your expertise, expressing your creativity, or connecting with like-minded individuals, starting a blog opens up a world of possibilities. In this step-by-step guide, we'll talk you through everything you need to start your blogging journey with confidence.


        </div>

    </div>

</body>
</html>
"""

# %% [markdown]
# #Q8. Create a simple list of items as mentioned in the below image

# %%
from IPython.display import HTML
HTML="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Requirements</h1>
    <ol type="i">
        <li>System with minimum i3 processor or better</li>
        <li>At least 4GB of RAM</li>
        <li>Working Internet Connection</li>
        <li>Dedication to learn</li>
    </ol>

</body>
</html>
"""
